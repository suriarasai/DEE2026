# %% [markdown]
# # Demo in class
# ## SQL Demo
# I am trying to create a SQL Query

# %%
print("Hello")

# %%
print("Hi this is a test"+"string")

# %%
# %sql
SELECT *
FROM rebu.taxi
WHERE taxi.Model = 'Toyota'
