-- %%
-- SCHEMA CHECK — verify column names and data types
-- Run DESCRIBE TABLE on key tables to confirm inferSchema
-- worked correctly (dates as DATE, numbers as INT/DOUBLE)
-- Check the main fact table schema
DESCRIBE TABLE booking;
